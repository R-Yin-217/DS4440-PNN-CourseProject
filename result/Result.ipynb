# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.cm import get_cmap

# %% [markdown]
# # Baseline(NLP)

# %%
# Data
BERT_high = np.array([
    [0.9276, 0.9356, 0.9364, 0.9374],
    [0.9354, 0.9382, 0.9376, 0.9392],
    [0.9314, 0.9272, 0.9302, 0.9316 ],
    [0.9212, 0.9342, 0.9376, 0.9396],
    [0.9362, 0.9368, 0.9346, 0.94]
])

BERT_low = np.array([
    [0.7166, 0.8668, 0.8808, 0.885],
    [0.5976, 0.8716, 0.8846, 0.8808],
    [0.4984, 0.4996, 0.826, 0.859],
    [0.6664, 0.866, 0.8774, 0.8802],
    [0.4926, 0.8606, 0.8832, 0.8854]
])

NLP_BEiT = np.array([
    [0.5442, 0.541, 0.5486, 0.5862],
    [0.5566, 0.4956, 0.5168, 0.6136],
    [0.5016, 0.5032, 0.5636, 0.5954],
    [0.5016, 0.536, 0.5658, 0.584],
    [0.5516, 0.4926, 0.5414, 0.582]
])



f1_high = np.array([
    [0.9275843593477461, 0.9356004533847776, 0.93639922662202, 0.9373988706200606],
    [0.9353963636590586, 0.9381969465639693, 0.9375880180018002, 0.9392012646602347],
    [0.9313995582066517, 0.9271098825169661, 0.9301844708995947, 0.9315948779424725],
    [0.9211090134139213, 0.9341400956383134, 0.9375808236508306, 0.9395936208414012],
    [0.9361816002096479, 0.936789801987045, 0.9345654417012662, 0.9400023043318239 ]
])

f1_low = np.array([
    [0.7002208073376037, 0.8666377945753669, 0.8807423050033165, 0.8849957169886595],
    [0.538000249486871, 0.8714267554788315, 0.8845650459876575, 0.8806757438631887],
    [0.3315570742124933, 0.33456939735346375, 0.825124051477869, 0.8589651546937924],
    [0.6348991323941923, 0.8658488751502664, 0.8773354288850121, 0.8802002635612757],
    [0.3253666833637053, 0.8601915758310108, 0.8831985045771716, 0.8853686383164088]
])

# Epoch
Epoch = np.arange(1, 5)

# Calculate the average
Acc_BERT_high = BERT_high.mean(axis=0)
Acc_BERT_low = BERT_low.mean(axis=0)
Acc_NLP_BEiT = NLP_BEiT.mean(axis=0)

# Plot
plt.figure(figsize=(8, 6))

# High Accuracy
plt.plot(Epoch, Acc_BERT_high, label="BERT (Pre-trained)", color="dodgerblue", marker='s', linestyle='-', linewidth=2, markersize=8)

# Low Accuracy
plt.plot(Epoch, Acc_BERT_low, label="BERT (Randomly Initialized)", color="orange", marker='s', linestyle='-.', linewidth=2, markersize=8)

# Experiment Accuracy
plt.plot(Epoch, Acc_NLP_BEiT, label="BEiT Receiving Texts (Pre-trained)", color="red", marker='^', linestyle='-', linewidth=2, markersize=8)

# Title and labels
plt.title("Model Accuracy Over Epochs", fontsize=18, weight='bold', pad=15)
plt.xlabel("Epoch", fontsize=14, weight='bold', labelpad=10)
plt.ylabel("Accuracy", fontsize=14, weight='bold', labelpad=10)

# Grid
plt.grid(which='both', linestyle='--', alpha=0.6)

# Ticks
plt.xticks(Epoch, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')

# Legend
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=False, borderpad=1, framealpha=0.5)
plt.ylim(top=1)

# Tight layout for better spacing
plt.tight_layout()

# Show plot
plt.savefig('Baseline_NLP')
plt.show()

# %% [markdown]
# # Baseline(CV)

# %%
# Data
BEiT_high = np.array([
    [0.9952, 0.995, 0.996, 0.9958],
    [0.9934, 0.994, 0.993, 0.9954],
    [0.9922, 0.996, 0.995, 0.996],
    [0.9954, 0.9944, 0.9958, 0.996],
    [0.9942, 0.9952, 0.9944, 0.996]
])

BEiT_low = np.array([
    [0.6208, 0.6802, 0.7218, 0.7356],
    [0.652, 0.7022, 0.7478, 0.752],
    [0.6582, 0.6832, 0.744, 0.7518],
    [0.6368, 0.6732, 0.7268, 0.739],
    [0.6426, 0.6334, 0.739, 0.7492]
])

CV_BERT = np.array([
    [0.6, 0.6298, 0.6756, 0.6828],
    [0.5626, 0.6534, 0.6866, 0.6914],
    [0.575, 0.6134, 0.6594, 0.675],
    [0.6024, 0.6412, 0.6546, 0.6648],
    [0.5192, 0.582, 0.6064, 0.6542]
])

# Epoch
Epoch = np.arange(1, 5)

# Calculate the average
Acc_BEiT_high = BEiT_high.mean(axis=0)
Acc_BEiT_low = BEiT_low.mean(axis=0)
Acc_CV_BERT = CV_BERT.mean(axis=0)

# Plot
plt.figure(figsize=(8, 6))

# High Accuracy
plt.plot(Epoch, Acc_BEiT_high, label="BEiT (Pre-trained)",color = 'dodgerblue', marker='s', linestyle='-', linewidth=2, markersize=8)

# Low Accuracy
plt.plot(Epoch, Acc_BEiT_low, label="BEiT (Randomly Initialized)", marker='s',color = 'orange', linestyle='-.', linewidth=2, markersize=8)

# Experiment Accuracy
plt.plot(Epoch, Acc_CV_BERT, label="BERT Receiving Images (Pre-trained)",color = 'red', marker='^', linestyle='-', linewidth=2, markersize=8)

# Title and labels
plt.title("Model Accuracy Over Epochs", fontsize=18, weight='bold', pad=15)
plt.xlabel("Epoch", fontsize=14, weight='bold', labelpad=10)
plt.ylabel("Accuracy", fontsize=14, weight='bold', labelpad=10)

# Grid
plt.grid(which='both', linestyle='--', alpha=0.6)

# Ticks
plt.xticks(Epoch, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')

# Legend
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=False, borderpad=1, framealpha=0.5)
plt.ylim(top=1)
# Tight layout for better spacing
plt.tight_layout()
plt.savefig("Baseline_CV")
# Show plot
plt.show()

# %% [markdown]
# # Inverse NLP

# %%
NLP_BEiT_ini = np.array([
    [0.797, 0.8461, 0.839, 0.8456],
    [0.7986, 0.8434, 0.843, 0.85],
    [0.8198, 0.8368, 0.8378, 0.844],
    [0.818, 0.8238, 0.836, 0.8382],
    [0.8182, 0.8432, 0.8472, 0.8512]
])

# Epoch
Epoch = np.arange(1, 5)

# Calculate the average
Acc_NLP_BEiT_ini = NLP_BEiT_ini.mean(axis=0)


# Plot
plt.figure(figsize=(8, 6))



# Low Accuracy
plt.plot(Epoch, Acc_BERT_low, label="BERT (Randomly Initialized)", color="orange", marker='s', linestyle='-.', linewidth=2, markersize=8)

# Experiment Accuracy
plt.plot(Epoch, Acc_NLP_BEiT, label="BEiT Receiving Texts (Pre-trained)", color="red", marker='^', linestyle='-', linewidth=2, markersize=8)

# Ini Experiment Accuracy
plt.plot(Epoch, Acc_NLP_BEiT_ini, label="BEiT Receiving Texts (Randomly Initialized)", color="green", marker='^', linestyle='-.', linewidth=2, markersize=8)

# Title and labels
plt.title("Model Accuracy Over Epochs", fontsize=18, weight='bold', pad=15)
plt.xlabel("Epoch", fontsize=14, weight='bold', labelpad=10)
plt.ylabel("Accuracy", fontsize=14, weight='bold', labelpad=10)

# Grid
plt.grid(which='both', linestyle='--', alpha=0.6)

# Ticks
plt.xticks(Epoch, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')

# Legend
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=False, borderpad=1, framealpha=0.5)
# Tight layout for better spacing
plt.tight_layout()
plt.savefig("Compare_NLP")
# Show plot
plt.show()

# %% [markdown]
# # Inverse CV

# %%
CV_BERT_ini = np.array([
    [0.612, 0.6442, 0.6428, 0.661],
    [0.6096, 0.6224, 0.6596, 0.6828],
    [0.6034, 0.636, 0.6382, 0.6838],
    [0.6078, 0.6466, 0.6642, 0.6888],
    [0.6036, 0.6102, 0.6532, 0.672] 
])

# Epoch
Epoch = np.arange(1, 5)

# Calculate the average
Acc_CV_BERT_ini = CV_BERT_ini.mean(axis=0)


# Plot
plt.figure(figsize=(8, 6))



# Low Accuracy
plt.plot(Epoch, Acc_BEiT_low, label="BEiT (Randomly Initialized)", color="orange", marker='s', linestyle='-.', linewidth=2, markersize=8)

# Experiment Accuracy
plt.plot(Epoch, Acc_CV_BERT, label="BERT Receiving Images (Pre-trained)", color="red", marker='^', linestyle='-', linewidth=2, markersize=8)

# Ini Experiment Accuracy
plt.plot(Epoch, Acc_CV_BERT_ini, label="BERT Receiving Images (Randomly Initialized)", color="green", marker='^', linestyle='-.', linewidth=2, markersize=8)

# Title and labels
plt.title("Model Accuracy Over Epochs", fontsize=18, weight='bold', pad=15)
plt.xlabel("Epoch", fontsize=14, weight='bold', labelpad=10)
plt.ylabel("Accuracy", fontsize=14, weight='bold', labelpad=10)

# Grid
plt.grid(which='both', linestyle='--', alpha=0.6)

# Ticks
plt.xticks(Epoch, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')

# Legend
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=False, borderpad=1, framealpha=0.5)
# Tight layout for better spacing
plt.tight_layout()
plt.savefig("Compare_CV")
# Show plot
plt.show()

# %% [markdown]
# # SimCLR

# %%
# Data
Sim_pre = np.array([
    [0.9174, 0.9176, 0.9178, 0.9162],
    [0.9182, 0.9228, 0.9238, 0.9238],
    [0.9142, 0.921, 0.9186, 0.921],
    [0.9114, 0.915, 0.917, 0.918],
    [0.9208, 0.9206, 0.9242, 0.9236]
])

Sim_ini = np.array([
    [0.9122, 0.9166, 0.9162, 0.9188],
    [0.9178, 0.9222, 0.92, 0.9232],
    [0.916, 0.9182, 0.924, 0.922],
    [0.9118, 0.9231, 0.9164, 0.9192],
    [0.9208, 0.9218, 0.9238, 0.9274]
])



# Epoch
Epoch = np.arange(1, 5)

# Calculate the average
Acc_Sim_pre = Sim_pre.mean(axis=0)
Acc_Sim_ini = Sim_ini.mean(axis=0)

# Plot
plt.figure(figsize=(8, 6))




# Baseline
plt.plot(Epoch, Acc_BEiT_high, label="BEiT (Pre-trained)",color="blue", marker='s', linestyle='-', linewidth=2, markersize=8)
plt.plot(Epoch, Acc_BEiT_low, label="BEiT (Randomly Initialized)", color="orange", marker='s', linestyle='-.', linewidth=2, markersize=8)

# Experiment Accuracy
plt.plot(Epoch, Acc_CV_BERT, label="BERT Receiving Images (Pre-trained)", color="red", marker='^', linestyle='-', linewidth=2, markersize=8)

# Ini Experiment Accuracy
plt.plot(Epoch, Acc_CV_BERT_ini, label="BERT Receiving Images (Randomly Initialized)", color="green", marker='^', linestyle='-.', linewidth=2, markersize=8)

#SimCLR
plt.plot(Epoch, Acc_Sim_pre, label="BERT Receiving Images (CL, Pre-trained)",color="magenta", marker='o', linestyle='-', linewidth=2, markersize=8)
plt.plot(Epoch, Acc_Sim_ini, label="BERT Receiving Images (CL, Randomly Initialized)", color="purple", marker='o', linestyle='-.', linewidth=2, markersize=8)


# Title and labels
plt.title("Model Accuracy Over Epochs", fontsize=18, weight='bold', pad=15)
plt.xlabel("Epoch", fontsize=14, weight='bold', labelpad=10)
plt.ylabel("Accuracy", fontsize=14, weight='bold', labelpad=10)

# Grid
plt.grid(which='both', linestyle='--', alpha=0.6)

# Ticks
plt.xticks(Epoch, fontsize=12, weight='bold')
plt.yticks(fontsize=12, weight='bold')

# Legend
plt.legend(fontsize=12, loc='lower left', frameon=True, shadow=False, borderpad=1, framealpha=0.5)
plt.ylim(top=1)
# Tight layout for better spacing
plt.tight_layout()
plt.savefig("CV")
# Show plot
plt.show()
